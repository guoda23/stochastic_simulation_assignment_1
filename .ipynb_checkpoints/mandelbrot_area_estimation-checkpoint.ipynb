# %%
import matplotlib.pyplot as plt
import numpy as np
import tqdm
import random
from functools import partial
import os 
import imageio 
from IPython.display import Image
from scipy import stats
from scipy.stats.qmc import LatinHypercube as lhs
import sympy
import pandas as pd
import csv

# %% [markdown]
# # Visualizing the Mandelbrot set

# %%
# Mandelbrot set function
def mandelbrot(c, max_iter):
    z = c
    for i in range(max_iter):
        if abs(z) > 2:
            return i
        z = z*z + c
    return i

# %%
# Parameters 
width, height = 800, 800
xmin, xmax = -2.0, 1.0
ymin, ymax = -1.5, 1.5
max_iter = 256

# Create an empty canvas
canvas = np.zeros((width, height))

# Initialize "true" Mandelbrot area (will be used as a reference to evaluate Monte Carlo)
pseudo_true_area = 0

# Generate the Mandelbrot set
for x in range(width):
    for y in range(height):
        # Calculate complex number (Mandelbrot input)
        zx, zy = x * (xmax - xmin) / (width - 1) + xmin, y * (ymax - ymin) / (height - 1) + ymin
        c = zx + zy * 1j

        # Set the pixel value based on the number of iterations
        pixel_value = mandelbrot(c, max_iter)
        canvas[y, x] = pixel_value

        if pixel_value == (max_iter - 1): pseudo_true_area +=1

pseudo_true_area = pseudo_true_area/(width * height) * (xmax - xmin) * (ymax - ymin)
print(f'The pseudo-true area value of the Mandelbrot set is {pseudo_true_area}')

# Create a colored image of the Mandelbrot set
plt.imshow(canvas, extent=(xmin, xmax, ymin, ymax))
plt.colorbar()
plt.savefig('MandelBrot', dpi=300, bbox_inches='tight', pad_inches=0.1)
plt.show()
# Out:
# The pseudo-true area value of the Mandelbrot set is 1.5179062500000002

# %% [markdown]
# # Computing the Area of the Mandelbrot set

# %%
def get_prime_squares(max_value):
    """
    This function outputs prime square values between 1 to some specified maximum value.

    Input: upper bound of prime square value

    Output: list of prime squares from 1 to the upper bound (or up to closest prime square below the upper bound)
    """
    # Get a sufficient amount of prime numbers for testing
    primes = list(sympy.primerange(0.5*(max_value)))
    # Add a prime square if within bounds
    prime_squares = [p**2 for p in primes if p**2 < max_value]

    return prime_squares


# Define a Latin Hypercube Sampling function
def latin_hypercube_sampling(n, random_state=None, visualize = False, orthogonal_sampling = False):
    """
    Function to create n samples in a 2 dimensional space.
    Input:
    - n: number of samples
    - visualization: True or False (False by default)
    - orthogonal sampling: True or False (False by default)
    (assumes variable ranges specified globally)

    Output:
    - x_samples
    - y_samples
    - Visualization of samples if parameter visualize = True
    """
    
    # Use scipy package to generate latin hypercube samples
    if orthogonal_sampling == True:
        strength = 2
    else:
        strength = 1
    
    latin_hypercube = lhs(d=2, strength = strength, seed = random_state)
    samples = latin_hypercube.random(n)

    # Scale the samples to the specified variable ranges
    x_samples = xmin + samples[:, 0] * (xmax - xmin)
    y_samples = ymin + samples[:, 1] * (ymax - ymin)

    #Shows drawn samples on a two dimensional grid
    if visualize:
        plt.scatter(x_samples, y_samples, s=10)
        plt.xlabel("X")
        plt.ylabel("Y")
        plt.title("Latin Hypercube Sampling Grid")
        grid_x = np.linspace(xmin, xmax, n+1)
        grid_y = np.linspace(ymin, ymax, n+1)
        plt.grid(True, which='both', linestyle='--', linewidth=0.5)
        plt.xticks(grid_x)
        plt.yticks(grid_y)
        plt.show()

    # Return the x and y samples
    return x_samples, y_samples

# %%
def calculate_reference_areas(xmin, xmax, ymin, ymax, i_max, s_values, num_runs, sampling_method = 'Uniform Sampling'):
    """
    Calculate reference areas for the given parameters.

    Parameters:
        xmin (float): Minimum x-coordinate.
        xmax (float): Maximum x-coordinate.
        ymin (float): Minimum y-coordinate.
        ymax (float): Maximum y-coordinate.
        i_max (int): Maximum number of iterations.
        s_values (list): List of sample sizes.
        num_runs (int): Number of simulation runs.
        sampling_method (str): Sampling method to use ('Uniform Sampling', 'Latin Hypercube Sampling', or 'Orthogonal Sampling').

    Returns:
        numpy.ndarray: Array containing reference areas for each sample size and run.
    """
        
    reference_areas = np.zeros((len(s_values), num_runs))

    for run in range(num_runs):
        np.random.seed(run)

        for idx, s in enumerate(s_values):
            reference_s = s
            reference_i_max = i_max
            reference_area = 0.0
            
            #Sample
            if sampling_method == 'Uniform Sampling':
                x_samples = np.random.uniform(xmin, xmax, reference_s)
                y_samples = np.random.uniform(ymin, ymax, reference_s)
            elif sampling_method == 'Latin Hypercube Sampling':
                x_samples, y_samples = latin_hypercube_sampling(s, random_state=run)
            elif sampling_method == 'Orthogonal Sampling':
                x_samples, y_samples = latin_hypercube_sampling(s, random_state=run, orthogonal_sampling=True)

                
            for x, y in zip(x_samples, y_samples):
                c = complex(x, y)
                z = c

                for _ in range(reference_i_max):
                    if abs(z) > 2.0:
                        break
                    z = z * z + c
                else:
                    reference_area += 1
                    
            reference_area = (reference_area / reference_s) * (xmax - xmin) * (ymax - ymin)
            reference_areas[idx, run] = reference_area

    return reference_areas


def calculate_area_estimations(xmin, xmax, ymin, ymax, i_max, s_values, num_runs, reference_areas, sampling_method = 'Uniform Sampling'):
    """
    Calculate area estimations for the given parameters based on reference areas.

    Parameters:
        xmin (float): Minimum x-coordinate.
        xmax (float): Maximum x-coordinate.
        ymin (float): Minimum y-coordinate.
        ymax (float): Maximum y-coordinate.
        i_max (int): Maximum number of iterations.
        s_values (list): List of sample sizes.
        num_runs (int): Number of simulation runs.
        reference_areas (numpy.ndarray): Array of reference areas from calculate_reference_areas function.
        sampling_method (str): Sampling method to use ('Uniform Sampling', 'Latin Hypercube Sampling', or 'Orthogonal Sampling').

    Returns:
        numpy.ndarray: Array containing area estimations for each iteration, sample size, and run.
    """
    
    area_estimations_sum = np.zeros((i_max, len(s_values), num_runs))

    for run in range(num_runs):
        np.random.seed(run)
        # print(f'run {run}/{num_runs}')
        for idx, s in enumerate(s_values):
            # print(f'sample size {s}')
            for j in range(1, i_max + 1):
                AM = 0.0
        
                if sampling_method == 'Uniform Sampling':
                    x_samples = np.random.uniform(xmin, xmax, s)
                    y_samples = np.random.uniform(ymin, ymax, s)
                elif sampling_method == 'Latin Hypercube Sampling':
                    x_samples, y_samples = latin_hypercube_sampling(s, random_state=run)
                elif sampling_method == 'Orthogonal Sampling':
                    x_samples, y_samples = latin_hypercube_sampling(s, random_state=run, orthogonal_sampling=True)

                
                for x, y in zip(x_samples, y_samples):
                    c = complex(x, y)
                    z = c
                    
                    for _ in range(j):
                        if abs(z) > 2.0:
                            break
                        z = z * z + c
                    else:
                        AM += 1
                        
                AM = (AM / s) * (xmax - xmin) * (ymax - ymin)
                area_estimations_sum[j - 1, idx, run] = AM

    return area_estimations_sum

# %%
#Orthogonal sampling only takes samples of size p^2 where p is a prime.
#Compute some potential sample sizes:
get_prime_squares(1400)
# Out:
# [4, 9, 25, 49, 121, 169, 289, 361, 529, 841, 961, 1369]

# %%
# Estimate Mandelbrot Area and calculate the absolute error using different sampling methods
# Define the parameters
xmin, xmax, ymin, ymax = -2.0, 1.0, -1.5, 1.5
i_max = 100
s_values = [49, 121, 169, 289, 361, 529] #Orthogonal Sampling only works on sample sizes of prime square values
num_runs = 30
sampling_methods = ['Uniform Sampling', 'Latin Hypercube Sampling', 'Orthogonal Sampling']

#Initiate variabes storing data for all sampling methods
all_areas = []
all_absolute_errors = []

# Get colors for the plots
color_cycle = plt.rcParams['axes.prop_cycle'].by_key()['color']


for sampling_method in sampling_methods:

    # Calculate reference areas
    reference_areas = calculate_reference_areas(xmin, xmax, ymin, ymax, i_max, s_values, num_runs, sampling_method = sampling_method)

    # Calculate area estimations
    area_estimations_sum = calculate_area_estimations(xmin, xmax, ymin, ymax, i_max, s_values, num_runs, reference_areas, sampling_method = sampling_method)
    all_areas.append(area_estimations_sum)

    # Calculate the reference area averages for each 's' value
    reference_areas_avg = np.mean(reference_areas, axis=1)

    plt.figure(figsize=(10, 6))

    # Calculate the average estimated area for each sample size
    average_area_by_sample = np.mean(area_estimations_sum, axis=2)
    
    # Plotting pseudo-true value line as reference
    plt.axhline(y=pseudo_true_area, color='r', label='Pseudo-true value', linewidth=2)

    # Plotting the estimated area for different sample sizes
    for idx, s in enumerate(s_values):
        plt.plot(range(1, i_max + 1), average_area_by_sample[:, idx], label=f'Area est., s = {s}', color=color_cycle[idx])

    # Reshape the reference_areas array
    reshaped_reference_areas = reference_areas.reshape(1, len(s_values), num_runs)

    # Calculate the absolute error based on s_values
    absolute_errors = np.abs(area_estimations_sum - reshaped_reference_areas)
    all_absolute_errors.append(absolute_errors)

    # Plot the absolute errors for different s_values
    for idx, s in enumerate(s_values):
        plt.plot(range(1, i_max + 1), absolute_errors[:, idx, :].mean(axis=1), color=color_cycle[idx], linestyle='--', label=f'Absolute Error, s = {s}')

    plt.xlabel('Number of Iterations (i)')
    plt.ylabel('Average Estimated Area and Absolute Error')
    plt.title(sampling_method + ':\nAverage Estimated Area and Absolute Error for Different Sample Sizes')
    plt.ylim(bottom=0, top=3)
    plt.xlim(left=0, right=100)
    plt.legend(loc='upper right', bbox_to_anchor=(1.28, 0.8), borderaxespad=0.)
    plt.grid()
    plt.savefig(f'{sampling_method}', dpi=300, bbox_inches='tight', pad_inches=0.1)
    plt.show()

# %%
# Lists to store data for confidence intervals
area_data_list, abs_error_data_list = [], []

# Loop over sampling methods
for method_idx, sampling_method in enumerate(sampling_methods):
    # Lists to store data for confidence intervals of area and absolute error
    i_area_list, s_area_list, area_list, ci_upper_area_list, ci_lower_area_list = [], [], [], [], []
    i_abs_error_list, s_abs_error_list, abs_error_list, ci_upper_abs_error_list, ci_lower_abs_error_list = [], [], [], [], []

    # Loop over 'i' values
    for i in range(5, i_max + 1, 5):  # Save every 5 iterations
        # Loop over 's' values
        for idx, s in enumerate(s_values):
            # Calculate the mean and standard deviation for the confidence interval of area
            mean_estimation_area = np.mean(all_areas[method_idx][i - 1, idx])
            std_estimation_area = np.std(all_areas[method_idx][i - 1, idx], ddof=1)

            # Calculate the confidence interval for the estimated area
            margin_of_error_area = stats.t.ppf(1 - 0.025, num_runs - 1) * (std_estimation_area / np.sqrt(num_runs))
            confidence_interval_area = (
                mean_estimation_area - margin_of_error_area,
                mean_estimation_area + margin_of_error_area
            )

            # Calculate the mean and standard deviation for the confidence interval of absolute error
            mean_abs_error = np.mean(all_absolute_errors[method_idx][i - 1, idx])
            std_abs_error = np.std(all_absolute_errors[method_idx][i - 1, idx], ddof=1)

            # Calculate the confidence interval for the absolute error
            margin_of_error_abs_error = stats.t.ppf(1 - 0.025, num_runs - 1) * (std_abs_error / np.sqrt(num_runs))
            confidence_interval_abs_error = (
                mean_abs_error - margin_of_error_abs_error,
                mean_abs_error + margin_of_error_abs_error
            )

            # Append data to lists for estimated area
            i_area_list.append(i)
            s_area_list.append(s)
            area_list.append(round(mean_estimation_area, 5))
            ci_upper_area_list.append(round(confidence_interval_area[1], 5))
            ci_lower_area_list.append(round(confidence_interval_area[0], 5))

            # Append data to lists for absolute error
            i_abs_error_list.append(i)
            s_abs_error_list.append(s)
            abs_error_list.append(round(mean_abs_error, 5))
            ci_upper_abs_error_list.append(round(confidence_interval_abs_error[1], 5))
            ci_lower_abs_error_list.append(round(confidence_interval_abs_error[0], 5))

    # Combine lists into DataFrames for the current sampling method
    area_data_df = pd.DataFrame({
        'i': i_area_list,
        's': s_area_list,
        'Sampling Method': sampling_method,
        'Estimated Area': area_list,
        'CI Upper Area': ci_upper_area_list,
        'CI Lower Area': ci_lower_area_list
    })

    abs_error_data_df = pd.DataFrame({
        'i': i_abs_error_list,
        's': s_abs_error_list,
        'Sampling Method': sampling_method,
        'Estimated Absolute Error': abs_error_list,
        'CI Upper Abs Error': ci_upper_abs_error_list,
        'CI Lower Abs Error': ci_lower_abs_error_list
    })

    # Append DataFrames to the respective data lists
    area_data_list.append(area_data_df)
    abs_error_data_list.append(abs_error_data_df)

# Combine DataFrames for all sampling methods
combined_area_df = pd.concat(area_data_list, ignore_index=True)
combined_abs_error_df = pd.concat(abs_error_data_list, ignore_index=True)

# Save to CSV
combined_area_df.to_csv('sampling_areas_results_area2.csv', index=False)
combined_abs_error_df.to_csv('sampling_areas_results_abs_error2.csv', index=False)

# %%
# Read the CSV files
area_df = pd.read_csv('sampling_areas_results_area2.csv')
abs_error_df = pd.read_csv('sampling_areas_results_abs_error2.csv')

# Get unique sampling methods
sampling_methods = area_df['Sampling Method'].unique()

# Define color cycle for different sample sizes
color_cycle = plt.rcParams['axes.prop_cycle'].by_key()['color']

# Plotting for each sampling method
for sampling_method in sampling_methods:
    # Filter data for the current sampling method
    area_method_df = area_df[area_df['Sampling Method'] == sampling_method]
    abs_error_method_df = abs_error_df[abs_error_df['Sampling Method'] == sampling_method]

    # Plotting Combined Area and Absolute Error
    plt.figure(figsize=(12, 8))
    # Plotting pseudo-true value line as reference
    plt.axhline(y=pseudo_true_area, color='r', label=f'Pseudo-true value: {pseudo_true_area:.4f}', linewidth=2)

    for idx, s in enumerate(area_method_df['s'].unique()):
        # Plotting Area
        s_area_data = area_method_df[area_method_df['s'] == s]
        plt.plot(s_area_data['i'], s_area_data['Estimated Area'], label=f'Area, s={s}', color=color_cycle[idx])
        plt.fill_between(s_area_data['i'], s_area_data['CI Lower Area'], s_area_data['CI Upper Area'], alpha=0.3, color=color_cycle[idx])

        # Plotting Absolute Error
        s_error_data = abs_error_method_df[abs_error_method_df['s'] == s]
        plt.plot(s_error_data['i'], s_error_data['Estimated Absolute Error'], label=f'Abs. Error, s={s}', linestyle='--', color=color_cycle[idx])
        plt.fill_between(s_error_data['i'], s_error_data['CI Lower Abs Error'], s_error_data['CI Upper Abs Error'], alpha=0.3, color=color_cycle[idx])

    plt.title(f'{sampling_method}: Estimated Area and Absolute Error with Confidence Intervals')
    plt.xlabel('Number of Iterations (i)')
    plt.ylabel('Estimated Area / Estimated Absolute Error')
    plt.ylim(bottom=0, top=3)
    plt.xlim(left=0, right=100)
    plt.legend(loc='upper right', bbox_to_anchor=(1.28, 0.8), borderaxespad=0.)
    plt.grid()
    plt.savefig(f'{sampling_method}', dpi=300, bbox_inches='tight', pad_inches=0.1)
    plt.show()

# %% [markdown]
# # Method to improve convergence : Importance Sampling

# %%
# Define the weighting functions
def weighting_function(x, y, a, xmin, xmax, ymin, ymax):
    """
    Calculate the weight based on the distance to the boundary.

    Parameters:
        x (float): x-coordinate.
        y (float): y-coordinate.
        a (float): Weighting parameter.
        xmin (float): Minimum x-coordinate of the rectangular region.
        xmax (float): Maximum x-coordinate of the rectangular region.
        ymin (float): Minimum y-coordinate of the rectangular region.
        ymax (float): Maximum y-coordinate of the rectangular region.

    Returns:
        float: Weight based on the distance to the boundary.
    """
    distance_to_boundary = np.sqrt(x**2 + y**2)
    return np.exp(a * distance_to_boundary)

def rbf_weighting(x, y, a, xmin, xmax, ymin, ymax):
    """
    Calculate the weight based on the Radial Basis Function (RBF).

    Parameters:
        x (float): x-coordinate.
        y (float): y-coordinate.
        a (float): Weighting parameter.
        xmin (float): Minimum x-coordinate of the rectangular region.
        xmax (float): Maximum x-coordinate of the rectangular region.
        ymin (float): Minimum y-coordinate of the rectangular region.
        ymax (float): Maximum y-coordinate of the rectangular region.

    Returns:
        float: Weight based on the Radial Basis Function (RBF).
    """
    # Calculate the maximum distance from the origin in the rectangular region
    max_distance = np.sqrt(max((xmax - xmin)**2, (ymax - ymin)**2))
    # RBF weighting function
    return np.exp(-a * np.sqrt((x - (xmin + xmax) / 2)**2 + (y - (ymin + ymax) / 2)**2) / max_distance)

# %%
def calculate_area_estimations_with_importance_sampling(xmin, xmax, ymin, ymax, i_max, s_values, num_runs, total_area, weighting_function):
    """
    Calculate area estimations with importance sampling for the given parameters.

    Parameters:
        xmin (float): Minimum x-coordinate.
        xmax (float): Maximum x-coordinate.
        ymin (float): Minimum y-coordinate.
        ymax (float): Maximum y-coordinate.
        i_max (int): Maximum number of iterations.
        s_values (list): List of sample sizes.
        num_runs (int): Number of simulation runs.
        total_area (numpy.ndarray): Array of total areas calculated using calculate_reference_areas.
        weighting_function (function): Weighting function to use for importance sampling.

    Returns:
        numpy.ndarray: Array containing area estimations with importance sampling for each iteration, sample size, and run.
    """
    area_estimations_sum = np.zeros((i_max, len(s_values), num_runs))
    for run in range(num_runs):
        np.random.seed(run)

        for idx, s in enumerate(s_values):
            for j in range(1, i_max + 1):
                AM = 0.0
                for _ in range(s):
                    # Sample according to the weighting function
                    x = np.random.uniform(xmin, xmax)
                    y = np.random.uniform(ymin, ymax)
                    weight = weighting_function(x, y, a, xmin, xmax, ymin, ymax)

                    c = complex(x, y)
                    z = c
                    for _ in range(j):
                        if abs(z) > 2.0:
                            break
                        z = z * z + c
                    else:
                        AM += weight
                AM = (AM / s) * total_area[idx]
                area_estimations_sum[j - 1, idx, run] += AM
                
    return area_estimations_sum

# %%
# Set the parameters
xmin, xmax, ymin, ymax = -2.0, 1.0, -1.5, 1.5
i_max = 100
s_values = [49, 121, 169, 289, 361, 529] #Orthogonal Sampling only works on sample sizes of prime square values
num_runs = 30
total_area = np.ones(len(s_values)) * (xmax - xmin) * (ymax - ymin)

# Calculate the maximum distance from the origin in the rectangular region; used in quadratic weighting
max_distance = np.sqrt(max((xmax - xmin)**2, (ymax - ymin)**2))

# Adjust the a value based on the desired spread of influence; used in quadratic weighting
a = 1.0 / (2 * max_distance)

# %%
# Calculate area estimations with importance sampling using the quadratic weighting function
area_estimations_edge = calculate_area_estimations_with_importance_sampling(xmin, xmax, ymin, ymax, i_max, s_values, num_runs, total_area, weighting_function)

# Calculate area estimations with importance sampling using the quadratic weighting function
area_estimations_rbf = calculate_area_estimations_with_importance_sampling(xmin, xmax, ymin, ymax, i_max, s_values, num_runs, total_area, rbf_weighting)

# %%
# Calculate reference areas
reference_areas = calculate_reference_areas(xmin, xmax, ymin, ymax, i_max, s_values, num_runs)

# Calculate the reference area averages for each 's' value
reference_areas_avg = np.mean(reference_areas, axis=1)

# %%
# Calculate the average estimated area for each sample size
average_area_edge = np.mean(area_estimations_edge, axis=2)
average_area_rbf = np.mean(area_estimations_rbf, axis=2)

#Store data
all_areas.append(area_estimations_edge)
all_areas.append(area_estimations_rbf)

# Calculate the absolute error for each weighting function
error_edge = np.abs(average_area_edge - reference_areas_avg)
error_rbf = np.abs(average_area_rbf - reference_areas_avg)

#Store data
all_absolute_errors.append(error_edge)
all_absolute_errors.append(error_rbf)

# %%
# Set up subplots, colors
fig, axes = plt.subplots(1, 2, figsize=(18, 6))
color_cycle = plt.rcParams['axes.prop_cycle'].by_key()['color']
plt.rcParams.update({'font.size': 14})

#Plot the reference area line with pseudo-true value
axes[0].axhline(y=pseudo_true_area, color='r', label='Pseudo-true value', linewidth=2)
axes[1].axhline(y=pseudo_true_area, color='r', linewidth=2)

# Plotting the estimated area for different sample sizes in each subplot
for idx, s in enumerate(s_values):
    axes[0].plot(range(1, i_max + 1), average_area_edge[:, idx], label=f'Area est., s = {s}', color = color_cycle[idx])
    axes[1].plot(range(1, i_max + 1), average_area_rbf[:, idx], color = color_cycle[idx])

# Set common labels and title
for ax in axes:
    ax.set_xlabel('Number of Iterations (i)')
    ax.set_ylabel('Average Estimated Area and Absolute Error')
    ax.set_ylim(bottom = 0, top = 3)
    ax.set_xlim(left = 0, right = 100)
    ax.tick_params(axis='both', labelsize=12) #Increase font size
    ax.grid()

# Set individual titles
axes[0].set_title('Edge Method')
axes[1].set_title('RBF Method')

plt.suptitle('Importance Sampling: Average Estimated Area and Absolute Errors for Different Sample Sizes')

# Sample sizes
s_values = [49, 121, 169, 289, 361, 529] #Orthogonal Sampling only works on sample sizes of prime square values

# Plotting the absolute error

# Plot for Edge Method
for idx, s in enumerate(s_values):
    axes[0].plot(range(1, i_max + 1), error_edge[:, idx], label=f'Absolute Error, s = {s}', linestyle='--', color = color_cycle[idx])

# Plot for RBF Method
for idx, s in enumerate(s_values):
    axes[1].plot(range(1, i_max + 1), error_rbf[:, idx], linestyle='--', color = color_cycle[idx])

fig.legend(loc='upper right', bbox_to_anchor=(1.17, 0.8))
plt.tight_layout()
plt.savefig('importance_sampling', dpi=300, bbox_inches='tight', pad_inches=0.1)
plt.show()

# %%
# Define parameters
i_max = 100
s_values = [49, 121, 169, 289, 361, 529]
num_runs = 30
sampling_methods = ['Edge Sampling', 'RBF Sampling']

# Lists to store data for confidence intervals
area_data_list, abs_error_data_list = [], []

# Loop over sampling methods
for method_idx, sampling_method in enumerate(sampling_methods):
    # Lists to store data for confidence intervals of area and absolute error
    i_area_list, s_area_list, area_list, ci_upper_area_list, ci_lower_area_list = [], [], [], [], []
    i_abs_error_list, s_abs_error_list, abs_error_list, ci_upper_abs_error_list, ci_lower_abs_error_list = [], [], [], [], []

    # Loop over 'i' values
    for i in range(5, i_max + 1, 5):  # Save every 5 iterations
        # Loop over 's' values
        for idx, s in enumerate(s_values):
            # Calculate the mean and standard deviation for the confidence interval of area
            mean_estimation_area = np.mean(all_areas[method_idx + 3][i - 1, idx])
            std_estimation_area = np.std(all_areas[method_idx + 3][i - 1, idx], ddof=1)

            # Calculate the confidence interval for the estimated area
            margin_of_error_area = stats.t.ppf(1 - 0.025, num_runs - 1) * (std_estimation_area / np.sqrt(num_runs))
            confidence_interval_area = (
                mean_estimation_area - margin_of_error_area,
                mean_estimation_area + margin_of_error_area
            )

            # Calculate the mean and standard deviation for the confidence interval of absolute error
            mean_abs_error = np.mean(all_absolute_errors[method_idx][i - 1, idx])
            std_abs_error = np.std(all_absolute_errors[method_idx][i - 1, idx], ddof=1)

            # Calculate the confidence interval for the absolute error
            margin_of_error_abs_error = stats.t.ppf(1 - 0.025, num_runs - 1) * (std_abs_error / np.sqrt(num_runs))
            confidence_interval_abs_error = (
                mean_abs_error - margin_of_error_abs_error,
                mean_abs_error + margin_of_error_abs_error
            )

            # Append data to lists for estimated area
            i_area_list.append(i)
            s_area_list.append(s)
            area_list.append(round(mean_estimation_area, 5))
            ci_upper_area_list.append(round(confidence_interval_area[1], 5))
            ci_lower_area_list.append(round(confidence_interval_area[0], 5))

            # Append data to lists for absolute error
            i_abs_error_list.append(i)
            s_abs_error_list.append(s)
            abs_error_list.append(round(mean_abs_error, 5))
            ci_upper_abs_error_list.append(round(confidence_interval_abs_error[1], 5))
            ci_lower_abs_error_list.append(round(confidence_interval_abs_error[0], 5))
    
    # Combine lists into DataFrames for the current sampling method
    area_data_df = pd.DataFrame({
        'i': i_area_list,
        's': s_area_list,
        'Sampling Method': sampling_method,
        'Estimated Area': area_list,
        'CI Upper Area': ci_upper_area_list,
        'CI Lower Area': ci_lower_area_list
    })

    abs_error_data_df = pd.DataFrame({
        'i': i_abs_error_list,
        's': s_abs_error_list,
        'Sampling Method': sampling_method,
        'Estimated Absolute Error': abs_error_list,
        'CI Upper Abs Error': ci_upper_abs_error_list,
        'CI Lower Abs Error': ci_lower_abs_error_list
    })

    # Append DataFrames to the respective data lists
    area_data_list.append(area_data_df)
    abs_error_data_list.append(abs_error_data_df)

# Combine DataFrames for all sampling methods
combined_area_df = pd.concat(area_data_list, ignore_index=True)
combined_abs_error_df = pd.concat(abs_error_data_list, ignore_index=True)

# Save to CSV
combined_area_df.to_csv('sampling_areas_results_area_imp.csv', index=False)
combined_abs_error_df.to_csv('sampling_areas_results_abs_error_imp.csv', index=False)

# %%
# Read the CSV files
area_df = pd.read_csv('sampling_areas_results_area_imp.csv')
abs_error_df = pd.read_csv('sampling_areas_results_abs_error_imp.csv')

sampling_methods = area_df['Sampling Method'].unique()

# Define a color map for different sample sizes
color_cycle = plt.rcParams['axes.prop_cycle'].by_key()['color']

# Plotting for each sampling method
for sampling_method in sampling_methods:
    # Filter data for the current sampling method
    area_method_df = area_df[area_df['Sampling Method'] == sampling_method]
    abs_error_method_df = abs_error_df[abs_error_df['Sampling Method'] == sampling_method]
    
    # Plotting Area and Absolute Error in the same plot
    plt.figure(figsize=(14, 8))

    # Plotting Area
    for idx, s in enumerate(area_method_df['s'].unique()):
        s_data = area_method_df[area_method_df['s'] == s]
        plt.plot(s_data['i'], s_data['Estimated Area'], label=f'Area, s = {s}', color=color_cycle[idx])
        plt.fill_between(s_data['i'], s_data['CI Lower Area'], s_data['CI Upper Area'], alpha=0.3, color=color_cycle[idx])
        
    # Plotting Absolute Error
    for idx, s in enumerate(abs_error_method_df['s'].unique()):
        s_data = abs_error_method_df[abs_error_method_df['s'] == s]
        plt.plot(s_data['i'], s_data['Estimated Absolute Error'], linestyle='--', label=f'Abs. Error, s = {s}', color=color_cycle[idx])
        plt.fill_between(s_data['i'], s_data['CI Lower Abs Error'], s_data['CI Upper Abs Error'], alpha=0.3, color=color_cycle[idx])

    plt.axhline(y=pseudo_true_area, color='r', label=f'Pseudo-true value: {pseudo_true_area:.4f}', linewidth=2)
    plt.title(f'{sampling_method}: Estimated Area and Absolute Error with Confidence Intervals')
    plt.xlabel('Number of Iterations (i)')
    plt.ylabel('Estimated Area / Estimated Absolute Error')
    plt.ylim(bottom=0, top=3)
    plt.xlim(left=0, right=100)
    plt.legend(loc='upper right', bbox_to_anchor=(1.28, 0.8), borderaxespad=0.)
    plt.grid()
    plt.savefig(f'{sampling_method}_output.png', dpi=300, bbox_inches='tight', pad_inches=0.1)
    plt.show()

# %% [markdown]
# # Compare across sampling methods

# %%
#Plot areas and errors for different sampling methods, sample size fixed

#Set index of desired sample (refer back to s_values)
sample_idx  = 1

legend_labels = ['Uniform', 'Latin Hypercube', 'Orthogonal', 'Importance (weighting f.)', 'Importance (RBF weighting)']

# Plotting prep
plt.figure(figsize=(10, 6))
color_cycle = plt.rcParams['axes.prop_cycle'].by_key()['color']
plt.rcParams.update({'font.size': 10})

#Plot the reference area value
plt.axhline(y=pseudo_true_area, color='r', label=f'Pseudo-true value', linewidth=2)

#Areas of different sampling methods for s=49
for idx, area in enumerate(all_areas):
    plt.plot(range(1, i_max+1), np.mean(area, axis=2)[:, sample_idx], color = color_cycle[idx], label = f'Area est: {legend_labels[idx]}')

# Absolute errors of different sampling methods for s=49
for idx, errors in enumerate(all_absolute_errors):
    if len(errors.shape) == 3:
        plt.plot(range(1, i_max+1), errors.mean(axis=2)[:, sample_idx], color = color_cycle[idx], linestyle = '--', label = f'Absolute Error: {legend_labels[idx]}')
    else:
        plt.plot(range(1, i_max+1), errors[:, sample_idx], color = color_cycle[idx], linestyle = '--', label = f'Absolute Error: {legend_labels[idx]}')


plt.xlabel('Number of Iterations (i)')
plt.ylabel('Average Estimated Area and Absolute Error')
plt.title(f'Average Estimated Area and Absolute Error for Different Sampling Methods (Sample Size = {s_values[sample_idx]})')
plt.ylim(bottom=0, top=3)
plt.xlim(left=0, right=100)
plt.legend(loc = 'upper right', bbox_to_anchor=(1.52, 0.8))
plt.grid()
plt.savefig(f'method_comparison_s{s_values[sample_idx]}', dpi=300, bbox_inches='tight', pad_inches=0.1)
plt.show()

# %% [markdown]
# # T-tests

# %%
methods = ['Uniform', 'Latin Hypercube', 'Orthogonal', 'Importance (Edge f.)', 'Importance (RBF weighting)']

#data variable contains three dimensions where 0th is area per iteration values, 1st is samples, 2nd is runs

for method_idx, data in enumerate(all_areas):
    print(f'{methods[method_idx]}:')
    for s_idx, s in enumerate(s_values):
        #Slicing: maximum iteration (99th), sample index, take all runs.
        statistic, p_value = stats.ttest_1samp(data[99, s_idx, :], pseudo_true_area) 
        print(f'For sample size {s}, t-test p-value is {p_value:.5f}')
    print('\n')
# Out:
# Uniform:
# For sample size 49, t-test p-value is 0.54668
# For sample size 121, t-test p-value is 0.71829
# For sample size 169, t-test p-value is 0.30831
# For sample size 289, t-test p-value is 0.11451
# For sample size 361, t-test p-value is 0.31636
# For sample size 529, t-test p-value is 0.17363
#
#
# Latin Hypercube:
# For sample size 49, t-test p-value is 0.27751
# For sample size 121, t-test p-value is 0.00711
# For sample size 169, t-test p-value is 0.01886
# For sample size 289, t-test p-value is 0.35551
# For sample size 361, t-test p-value is 0.76701
# For sample size 529, t-test p-value is 0.00080
#
#
# Orthogonal:
# For sample size 49, t-test p-value is 0.08235
# For sample size 121, t-test p-value is 0.15764
# For sample size 169, t-test p-value is 0.03193
# For sample size 289, t-test p-value is 0.00105
# For sample size 361, t-test p-value is 0.00001
# For sample size 529, t-test p-value is 0.00994
#
#
# Importance (Edge f.):
# ...
